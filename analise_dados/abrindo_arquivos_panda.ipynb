# %%
import pandas as pd

dados = pd.read_csv('./fifa.csv')
# dados_xlsx = pd.read_excel('./fifa.xlsx')
# dados_txt = pd.read_csv('./fifa.csv', delimiter = '\t')
# dados_html = pd.read_html('https://jojowiki.com/Category:Characters/pt-br')

dados

# %%
dados.head(5)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
dados.tail(8)

# %%
dados.index
dados.columns

# %%
dados[['ID', 'Name', 'Nationality', 'Wage']].head(5)

# %%
# primeiro linha depois coluna
dados.iloc[2,2]

# %%
dados.loc[dados['Nationality'] == 'Brazil'].head(10)
dados.loc[dados['Age'] == 16].head()

# %%
dados.sort_values(['Name', 'Age'])

# %%
dados[['ID', 'Name', 'Nationality', 'Weight']].sort_values('Weight')

# %%
# dados['Total'] = dados['Acceleration'] + dados['Agility'] + dados['Reactions']
# dados[['ID', 'Name', 'Total']].loc[dados['Name'] == 'Cristiano Ronaldo']
# dados[['ID', 'Name', 'Total']].sort_values('Total', ascending=False)
# dados = dados[['ID', 'Name', 'Total']]
dados

# %%
dados.head(5).to_csv('./dados1_5.csv', index= False)

# tem qu ebeixar uma biblioteca
# dados.head(5).to_excel('./dados1_5.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[84], line 2
#       1 dados.head(5).to_csv('./dados1_5.csv', index= False)
# ----> 2 dados.head(5).to_excel('./dados1_5.xlsx')
#
# File c:\Users\dudut\anaconda3\envs\pb_sprint_2\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
